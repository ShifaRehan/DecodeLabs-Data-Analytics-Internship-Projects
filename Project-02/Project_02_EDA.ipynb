# %% [markdown]
# # **Project # 02 EXPLORATORY DATA ANALYSIS (EDA)**

# %% [markdown]
# ## ***Project Details***
#
# | **Field** | **Details** |
# |--------|----------|
# | **Name** | Shifa Rehan |
# | **Submission Date** | 10-07-2026 |
# | **Tools Used** | Python, Pandas, NumPy, Matplotlib, Seaborn, Jupyter Notebook |

# %% [markdown]
# # ***Objective***
# The objective of this project is to perform Exploratory Data Analysis (EDA) on the cleaned dataset to identify patterns, trends and outliers, distributions, creating visualizations and generate meaningful insights using Python.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Clean Dataset

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Cleaned_Dataset.csv")
df.head(21)
# Out:
#       OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0   ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1   ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2   ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3   ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4   ORD200004  2025-05-08     C81840  Printer         4     626.01
# 5   ORD200005  2023-10-23     C37249    Phone         2     245.86
# 6   ORD200006  2025-06-17     C83492   Laptop         1     664.42
# 7   ORD200007  2023-05-12     C41460  Monitor         5     149.55
# 8   ORD200008  2025-04-02     C26817    Phone         2     134.28
# 9   ORD200009  2023-11-21     C31946     Desk         4     509.38
# 10  ORD200010  2023-12-29     C43443   Tablet         5     625.97
# 11  ORD200011  2024-02-17     C93861  Monitor         3      49.14
# 12  ORD200012  2024-10-15     C38785  Monitor         2     180.50
# ...

# %%
df.describe()
# Out:
#           Quantity    UnitPrice  ItemsInCart   TotalPrice
# count  1200.000000  1200.000000  1200.000000  1200.000000
# mean      2.945833   356.412750     5.485000  1053.968300
# std       1.407557   197.177146     2.281983   819.856558
# min       1.000000    11.390000     1.000000    11.390000
# 25%       2.000000   186.062500     4.000000   410.520000
# 50%       3.000000   364.210000     5.000000   823.615000
# 75%       4.000000   521.570000     7.000000  1578.475000
# max       5.000000   699.930000    10.000000  3456.400000

# %% [markdown]
# # Median

# %%
df["Quantity"].median()
# Out:
# 3.0

# %%
df["TotalPrice"].median()
# Out:
# 823.615

# %% [markdown]
# # Product Analysis

# %%
df["Product"].value_counts()
# Out:
# Product
# Printer    181
# Tablet     179
# Chair      178
# Laptop     173
# Desk       170
# Monitor    163
# Phone      156
# Name: count, dtype: int64

# %% [markdown]
# # Payment Method Analysis

# %%
df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Online         258
# Cash           246
# Credit Card    234
# Debit Card     232
# Gift Card      230
# Name: count, dtype: int64

# %% [markdown]
# # Order Status Analysis

# %%
df["OrderStatus"].value_counts()
# Out:
# OrderStatus
# Cancelled    250
# Returned     247
# Pending      237
# Shipped      235
# Delivered    231
# Name: count, dtype: int64

# %% [markdown]
# # Referral Source Analysis

# %%
df["ReferralSource"].value_counts()
# Out:
# ReferralSource
# Instagram    259
# Email        250
# Google       241
# Facebook     228
# Referral     222
# Name: count, dtype: int64

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(6.5,6.5))

plt.boxplot(df["TotalPrice"])

plt.title("Outliers in Total Price")

plt.show()

# %%
Q1 = df["TotalPrice"].quantile(0.25)
Q3 = df["TotalPrice"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[(df["TotalPrice"] < lower_limit) | (df["TotalPrice"] > upper_limit)]

outliers
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 107   ORD200107  2023-03-27     C16775  Printer         5     670.75
# 326   ORD200326  2024-07-01     C65986   Laptop         5     670.48
# 328   ORD200328  2023-02-28     C18404   Tablet         5     674.04
# 469   ORD200469  2023-11-26     C13877    Chair         5     676.98
# 632   ORD200632  2023-05-02     C67260   Laptop         5     678.16
# 789   ORD200789  2023-08-17     C57276   Tablet         5     691.28
# 1065  ORD201065  2023-10-30     C47778  Printer         5     666.80
# 1122  ORD201122  2023-06-07     C38840  Monitor         5     678.19
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 107      848 Main St     Gift Card     Shipped    TRK34392124            8
# 326      273 Main St     Gift Card    Returned    TRK98353867            5
# 328      546 Main St        Online   Cancelled    TRK89401624            7
# ...

# %% [markdown]
# # Monthly Trend

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Month"] = df["Date"].dt.month_name()

# %%
df["Month"].value_counts().sort_index()
# Out:
# Month
# April        113
# August        79
# December      87
# February     106
# January      106
# July          87
# June         147
# March        128
# May          120
# November      76
# October       78
# September     73
# Name: count, dtype: int64

# %% [markdown]
# # Order Status

# %%
status = df["OrderStatus"].value_counts()

plt.figure(figsize=(6.5,6.5))
status.plot(kind="bar", color="lightgreen")

plt.title("Order Status Distribution")
plt.xlabel("Status")
plt.ylabel("Number of Orders")
plt.show()

# %% [markdown]
# # Payment Method Distribution

# %%
payment = df["PaymentMethod"].value_counts()

plt.figure(figsize=(6.5,6.5))
payment.plot(kind="pie", autopct="%1.1f%%")

plt.title("Payment Method Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# # Total Price Distribution

# %%
plt.hist(df["TotalPrice"], bins=10)

plt.title("Distribution of Total Price")
plt.xlabel("Total Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Monthly Sales Trend

# %%
df["Date"] = pd.to_datetime(df["Date"])

monthly_sales = df.groupby(df["Date"].dt.month_name())["TotalPrice"].sum()

plt.figure(figsize=(10,5))

monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")

plt.xlabel("Month")

plt.ylabel("Total Sales")

plt.grid(True)

plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
df[["Quantity","UnitPrice","ItemsInCart","TotalPrice"]].corr()
# Out:
#              Quantity  UnitPrice  ItemsInCart  TotalPrice
# Quantity     1.000000   0.014553     0.650061    0.615251
# UnitPrice    0.014553   1.000000     0.000602    0.717081
# ItemsInCart  0.650061   0.000602     1.000000    0.392540
# TotalPrice   0.615251   0.717081     0.392540    1.000000

# %%
plt.figure(figsize=(9,6))
sns.heatmap(
    df[["Quantity","UnitPrice","ItemsInCart","TotalPrice"]].corr(),
    annot=True,
    cmap="Blues"
)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## *Key Observations*
#
# - The average order value is **1053.96**.
# - Most customers use **online** as their payment method.
# - **Printer** is the most frequently ordered product.
# - **Instagram** generates the highest number of referrals.
# - A few high-value orders appear as outliers.

# %% [markdown]
# ## **Conclusion**
#
# Exploratory Data Analysis (EDA) was successfully performed on the cleaned dataset. Descriptive statistics, trends, and visualizations were used to understand customer behavior and order patterns. The analysis provided useful insights that can support future business decisions.
